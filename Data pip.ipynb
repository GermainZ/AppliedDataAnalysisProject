# %% [markdown]
# When describing the data, in particular, you should show (non-exhaustive list):
#
#     That you can handle the data in its size.
#     That you understand what’s into the data (formats, distributions, missing values, correlations, etc.).
#     That you considered ways to enrich, filter, transform the data according to your needs.
#     That you have updated your plan in a reasonable way, reflecting your improved knowledge after data acquaintance. In particular, discuss how your data suits your project needs and discuss the methods you’re going to use, giving their essential mathematical details in the notebook.
#     That your plan for analysis and communication is now reasonable and sound, potentially discussing alternatives to your choices that you considered but dropped.

# %% [markdown]
# # Milestone 2: Analyzing Success

# %%
# Imports.
import pandas as pd
import numpy as np
import os
# Spark doesn't support reading XML files natively, so we use spark-xml
# (source: <https://github.com/databricks/spark-xml/>)
# Note that we're using spark-xml 0.4.2 as that fixes <https://github.com/databricks/spark-xml/issues/92>,
# which is necessary to read our dataset. (0.4.2 isn't released yet, which is why we compiled it ourselves.)
os.environ['PYSPARK_SUBMIT_ARGS'] = '--jars spark-xml_2.11-0.4.2.jar pyspark-shell'
from pyspark.sql import SparkSession, SQLContext

# Paths.
DATASETS_DIR = './data/datasets'

# %% [markdown]
# # 1. Data Retrieval

# %% [markdown]
# The project datasets were retrieved from the following sources:
#
# - [Gitential Datasets for Open Source Projects (retrieved in January 2018)](https://github.com/gitential/datasets) (2.31 G): there is no unified dataset provided by Gitential (each repo's dataset is separate). We used a mixed Jupyter Notebook to extract all the datasets' links with a shell one-liner, and downloaded them with Python.
#
# - [GitHub API](https://developer.github.com/v3/) (? G): to augment our datasets, we're also using this API (with the [PyGithub Python library](https://github.com/PyGithub/PyGithub)) to obtain additional information about the repos we're interested in. We use the API to get the number of stars, forks and stargazers of a project. We also use the API to get each project's issues and each issue's comments (where applicable, since projects on GitHub can choose not to have an issues tracker).
# **<span style="color:green">(For implementation details, see `retrieve_additional_data_github.ipynb`)</span>**.
#
# - [StackOverflow Posts data dump](https://archive.org/details/stackexchange) (62 G): we asked for this dataset to be downloaded on the EPFL cluster.
#
# - [Reddit comments from 2005-12 to 2017-03](http://academictorrents.com/details/85a5bd50e4c365f8df70240ffd4ecc7dec59912b) (304 G): this dataset is available on the EPFL cluster.

# %% [markdown]
# # 2. Data Loading

# %% [markdown]
# ### <span style='color:green'> 2.1 - GitHub API data (Issues & Comments) </span>

# %%
# load issues data into dataframe 
issues_df = pd.read_csv('./data/github_issues.csv', index_col=0)

# display a sample
display(issues_df.head(3))
# Out:
#                                                         body  \
# 341328385  - fix bug #19992\r\n- 2 tests amended in frame...
# 341342552  - [x] closes #21792\r\n- [ ] tests added / pas...
# 341349059  May close #21905, will need to check with OP.\r\n
#
#                      closed_at  comments           created_at  \
# 341328385  2018-07-18 10:23:30         3  2018-07-15 15:18:30
# 341342552                  NaN        10  2018-07-15 18:49:01
# 341349059  2018-07-17 00:37:13        15  2018-07-15 20:16:15
#
#                                                   html_url  number   state  \
# 341328385  https://github.com/pandas-dev/pandas/pull/21921   21921  closed
# 341342552  https://github.com/pandas-dev/pandas/pull/21922   21922    open
# 341349059  https://github.com/pandas-dev/pandas/pull/21923   21923  closed
#
#                                                        title  \
# 341328385  BUG:Clip with a list-like threshold with a nan...
# 341342552  Concatenation of series of differing types sho...
# 341349059     [BUG] change types to Py_ssize_t to fix #21905
#
#                     updated_at closed_by          user assignee assignees  \
# 341328385  2018-07-18 10:23:47   jreback       makbigc      NaN       NaN
# 341342552  2018-11-21 15:42:35       NaN        xhochy      NaN       NaN
# 341349059  2018-07-17 01:02:49   jreback  jbrockmendel      NaN       NaN
#
#                               labels milestone  \
# 341328385    ['Bug', 'Missing-data']    0.23.4
# 341342552  ['Bug', 'ExtensionArray']       NaN
# 341349059           ['32bit', 'Bug']    0.24.0
#
#                                               pull_request
# 341328385  https://github.com/pandas-dev/pandas/pull/21921
# 341342552  https://github.com/pandas-dev/pandas/pull/21922
# 341349059  https://github.com/pandas-dev/pandas/pull/21923

# %%
# load the comments data into a dataframe
comments_df = pd.read_csv('./data/github_comments.csv', index_col=0)

# display a sample
comments_df.head(5)
# Out:
#                                                         body  \
# 142689649  It seems OK to me. I assume we still have at l...
# 142690747  @srowen So this changes it so that all of the ...
# 142699766    [Test build #42915 has finished](https://amp...
# 142701746    [Test build #42916 has finished](https://amp...
# 142733640  cc'ing a few people: @mccheah (who wrote the o...
#
#                     created_at           updated_at     parent
# 142689649  2015-09-23 18:28:51  2015-09-23 18:28:51  107977847
# 142690747  2015-09-23 18:33:36  2015-09-23 18:33:36  107977847
# 142699766  2015-09-23 19:07:00  2015-09-23 19:07:00  107977847
# 142701746  2015-09-23 19:16:05  2015-09-23 19:16:05  107977847
# 142733640  2015-09-23 21:24:23  2015-09-23 21:24:23  108009077

# %% [markdown]
# **Note: this is only a sample of the data we want to retrieve. Therefore, we cannot perform correlation/distribution analysis yet (since we need the full data for that).**
#
# (This is because the GitHub API, which we're using to build this additional dataset, has an hourly limit of 5000 requests/hour. We're retrieving around 300,000 issues in total, spread across all the repositories we're studying, as well as all of their comments. In total, this amounts to half a million to a million requests. We expect this to finish around Monday. For implementation details, please check the `retrieve_additional_data_github.ipynb` notebook.)

# %% [markdown]
# ### <span style='color:green'> 2.2 - Projects Data (blames, and tags) </span>

# %%
# proper project name couldn't be identified for these 5 cases
# this was done manually to solve the issue
AMBIGUOUS_NAMES = {
    'apache-incubator-superset': 'apache-incubator/superset',
    'keras-team-keras': 'keras-team/keras',
    'pandas-dev-pandas': 'pandas-dev/pandas',
    'rust-lang-rust': 'rust-lang/rust',
    'scikit-learn-scikit-learn': 'scikit-learn/scikit-learn'
}
DIR_GITHUB_MAPPING = {}

# assign each directory with a github path
for dir_name in os.listdir(DATASETS_DIR):
    if dir_name in AMBIGUOUS_NAMES:
        github_path = AMBIGUOUS_NAMES[dir_name]
    else:
        github_path = dir_name.replace('-', '/')
    DIR_GITHUB_MAPPING[dir_name] = github_path
del DIR_GITHUB_MAPPING['.DS_Store']

# %%
# load commits into a data frame
commits = {}
for dir_name, github_path in DIR_GITHUB_MAPPING.items():
    commits[github_path] = pd.read_json('{}/{}/commits.json.gz'.format(DATASETS_DIR, dir_name))
commits_df = pd.concat(commits, names=['project'])
commits_df = commits_df.reset_index(level='project').reset_index(drop=True)

# %%
# display a sample
commits_df.head(5)
# Out:
#           project  age                               author_email  \
# 0  Microsoft/CNTK   -1  do****@stggpu1.redmond.corp.microsoft.com
# 1  Microsoft/CNTK   -1  do****@stggpu1.redmond.corp.microsoft.com
# 2  Microsoft/CNTK   -1                      jd*****@microsoft.com
# 3  Microsoft/CNTK   -1                       do****@microsoft.com
# 4  Microsoft/CNTK   -1                       do****@microsoft.com
#
#       author_email_dedup   author_name author_name_dedup         author_time  \
# 0  al*****@microsoft.com       unknown     Yinggong ZHAO 2014-07-29 10:12:20
# 1  al*****@microsoft.com       unknown     Yinggong ZHAO 2014-08-29 16:21:42
# 2  jd*****@microsoft.com  Jasha Droppo      Jasha Droppo 2014-08-31 12:27:42
# 3   do****@microsoft.com       Dong Yu           Dong Yu 2014-09-01 14:43:21
# 4   do****@microsoft.com       Dong Yu           Dong Yu 2014-09-02 17:16:40
#
#                              committer_email  committer_email_dedup  \
# 0  do****@stggpu1.redmond.corp.microsoft.com  al*****@microsoft.com
# 1  do****@stggpu1.redmond.corp.microsoft.com  al*****@microsoft.com
# 2                      jd*****@microsoft.com  jd*****@microsoft.com
# 3                       do****@microsoft.com   do****@microsoft.com
# 4                       do****@microsoft.com   do****@microsoft.com
#
#   committer_name   ...     comp_i delay  \
# 0        unknown   ...          0     0
# 1        unknown   ...     248008     0
# 2   Jasha Droppo   ...          0     0
# 3        Dong Yu   ...          0     0
# 4        Dong Yu   ...          3     0
#
#                                          id  ismerge  loc_d   loc_i  \
# 0  bc9b0d6b0aebc469b2f84664de590b59d6fdf79f    False      0       0
# 1  61694509551f38e031c74f3d9409b44fe50224cf    False      0  139349
# 2  9515bfbd104a5ba4f4214e2d883e8e3af2acd01c    False      0       0
# 3  52eabc6e8852b6a8342ae304a606663f7f8ae15f    False      1       0
# 4  f5a490c2afbffd515a9ddfbe3053e76bb9cbfe17    False      1       1
#
#                                              message  ndiffs  nfiles squashof
# 0                                             test\n       1       1       -1
# 1                            First Release of CNTK\n       1     492       -1
# 2  Added the ASR/TIMIT/decoding to ExampleSetups ...       1       6       -1
# 3               remove #include SimpleCNNBuilder.h\n       1       1       -1
# 4  remove ";" from "if (pass == ndlPassInitial);"...       1       1       -1
#
# [5 rows x 23 columns]

# %%
# load blames into a data frame
tags = {}
for dir_name, github_path in DIR_GITHUB_MAPPING.items():
    tags[github_path] = pd.read_json('{}/{}/tags.json.gz'.format(DATASETS_DIR, dir_name))
tags_df = pd.concat(tags, names=['project'])
tags_df = tags_df.reset_index(level='project').reset_index(drop=True)

# %%
# set id as the index
tags_df = tags_df.set_index('id')
# display a sample
tags_df.head(4)
# Out:
#                                                  project         author_time  \
# id
# a0a32466a95c7f907ebb66e7f879cc314ec1506f  Microsoft/CNTK 2016-01-22 10:15:34
# 35cb5738e7ef794177a2fff06892a39700722dee  Microsoft/CNTK 2016-06-14 18:29:56
# 56a2a15f64676ea4c0e0a0a681a57b19a46f64c6  Microsoft/CNTK 2016-01-25 20:53:43
# 2f9a48c71dc0a6097498cb7e90ac3b151ab536dd  Microsoft/CNTK 2016-02-05 11:06:20
#
#                                                                                  message  \
# id
# a0a32466a95c7f907ebb66e7f879cc314ec1506f
# 35cb5738e7ef794177a2fff06892a39700722dee
# 56a2a15f64676ea4c0e0a0a681a57b19a46f64c6  Release CNTK Beta (Windows+Linux) 2016-01-26\n
# 2f9a48c71dc0a6097498cb7e90ac3b151ab536dd  Release CNTK Beta (Windows+Linux) 2016-02-08\n
#
#                                                                      name  \
# id
# a0a32466a95c7f907ebb66e7f879cc314ec1506f             refs/tags/2015-12-08
# 35cb5738e7ef794177a2fff06892a39700722dee  refs/tags/feature/CNTKCustomMKL
# 56a2a15f64676ea4c0e0a0a681a57b19a46f64c6            refs/tags/r2016-01-26
# 2f9a48c71dc0a6097498cb7e90ac3b151ab536dd            refs/tags/r2016-02-08
#
#                                           type
# id
# a0a32466a95c7f907ebb66e7f879cc314ec1506f   1.0
# 35cb5738e7ef794177a2fff06892a39700722dee   1.0
# 56a2a15f64676ea4c0e0a0a681a57b19a46f64c6   1.0
# 2f9a48c71dc0a6097498cb7e90ac3b151ab536dd   1.0

# %% [markdown]
# ### <span style='color:green'> 2.3 - Stackflow data</span>

# %%
spark = SparkSession.builder.getOrCreate()
sqlContext = SQLContext(spark.sparkContext)

# Read the data.
df = sqlContext.read.format('com.databricks.spark.xml').options(rowTag='row').load('./data/Posts.xml')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-24862fdc5398> in <module>()
#       3
#       4 # Read the data.
# ----> 5 df = sqlContext.read.format('com.databricks.spark.xml').options(rowTag='row').load('./data/Posts.xml')
#
# ~/anaconda3/lib/python3.6/site-packages/pyspark/sql/readwriter.py in load(self, path, format, schema, **options)
#     164         self.options(**options)
#     165         if isinstance(path, basestring):
# --> 166             return self._df(self._jreader.load(path))
#     167         elif path is not None:
#     168             if type(path) != list:
#
# ~/anaconda3/lib/python3.6/site-packages/py4j/java_gateway.py in __call__(self, *args)
#    1253             proto.END_COMMAND_PART
#    1254
# -> 1255         answer = self.gateway_client.send_command(command)
#    1256         return_value = get_return_value(
#    1257             answer, self.gateway_client, self.target_id, self.name)
#
# ~/anaconda3/lib/python3.6/site-packages/py4j/java_gateway.py in send_command(self, command, retry, binary)
#     983         connection = self._get_connection()
#     984         try:
# --> 985             response = connection.send_command(command)
#     986             if binary:
#     987                 return response, self._create_connection_guard(connection)
#
# ~/anaconda3/lib/python3.6/site-packages/py4j/java_gateway.py in send_command(self, command)
#    1150
#    1151         try:
# -> 1152             answer = smart_decode(self.stream.readline()[:-1])
#    1153             logger.debug("Answer received: {0}".format(answer))
#    1154             if answer.startswith(proto.RETURN_MESSAGE):
#
# ~/anaconda3/lib/python3.6/socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
# Convert the CreationDate column to timestamps format.
df = df.withColumn('CreationDate', to_timestamp(df._CreationDate))
df = df.drop('_CreationDate').withColumnRenamed('CreationDate', '_CreationDate')

# Display some of the data.
pd.DataFrame(df.take(5), columns=df.columns)

# %% [markdown]
# ### <span style='color:green'> 2.4 - Reddit data</span>

# %%
# load the data germain

# %% [markdown]
# # 3. Data Inspection

# %% [markdown]
# ### <span style='color:green'> 2.1 - GitHub API data (Issues & Comments) </span>

# %%
display(issues_df.head(3))
# Out:
#                                                         body  \
# 341328385  - fix bug #19992\r\n- 2 tests amended in frame...
# 341342552  - [x] closes #21792\r\n- [ ] tests added / pas...
# 341349059  May close #21905, will need to check with OP.\r\n
#
#                      closed_at  comments           created_at  \
# 341328385  2018-07-18 10:23:30         3  2018-07-15 15:18:30
# 341342552                  NaN        10  2018-07-15 18:49:01
# 341349059  2018-07-17 00:37:13        15  2018-07-15 20:16:15
#
#                                                   html_url  number   state  \
# 341328385  https://github.com/pandas-dev/pandas/pull/21921   21921  closed
# 341342552  https://github.com/pandas-dev/pandas/pull/21922   21922    open
# 341349059  https://github.com/pandas-dev/pandas/pull/21923   21923  closed
#
#                                                        title  \
# 341328385  BUG:Clip with a list-like threshold with a nan...
# 341342552  Concatenation of series of differing types sho...
# 341349059     [BUG] change types to Py_ssize_t to fix #21905
#
#                     updated_at closed_by          user assignee assignees  \
# 341328385  2018-07-18 10:23:47   jreback       makbigc      NaN       NaN
# 341342552  2018-11-21 15:42:35       NaN        xhochy      NaN       NaN
# 341349059  2018-07-17 01:02:49   jreback  jbrockmendel      NaN       NaN
#
#                               labels milestone  \
# 341328385    ['Bug', 'Missing-data']    0.23.4
# 341342552  ['Bug', 'ExtensionArray']       NaN
# 341349059           ['32bit', 'Bug']    0.24.0
#
#                                               pull_request
# 341328385  https://github.com/pandas-dev/pandas/pull/21921
# 341342552  https://github.com/pandas-dev/pandas/pull/21922
# 341349059  https://github.com/pandas-dev/pandas/pull/21923

# %% [markdown]
# The following columns were dropped: 'updated_at', 'assignee' and 'number' because they do not provide any significant inforamtion for our analysis:
# - **'updated_at'**: We are more interested in the time it took for the issue to be closed and not when it was last updated because the reason for the change is not clear.
# - **'number'** (repo specific sequential ID): we already have the global tracking number (used as index for the data) and this does not provide any further inforamtion.
# - **'assignee'**: redundant data, information already present in assignees column.

# %%
# remove unneeded columns updated_at', 'number'
issues_df = issues_df.drop(['updated_at', 'number','assignee'], axis=1)

# display changed data
issues_df.head(5)
# Out:
#                                                         body  \
# 341328385  - fix bug #19992\r\n- 2 tests amended in frame...
# 341342552  - [x] closes #21792\r\n- [ ] tests added / pas...
# 341349059  May close #21905, will need to check with OP.\r\n
# 341349603  - [ ] <s>closes #16045</s><b>update</b>Not any...
# 341355270  Hi,\r\n\r\nThe `corr` method for DataFrames is...
#
#                      closed_at  comments           created_at  \
# 341328385  2018-07-18 10:23:30         3  2018-07-15 15:18:30
# 341342552                  NaN        10  2018-07-15 18:49:01
# 341349059  2018-07-17 00:37:13        15  2018-07-15 20:16:15
# 341349603  2018-09-08 02:46:54         6  2018-07-15 20:24:21
# 341355270                  NaN         2  2018-07-15 21:50:46
#
#                                                     html_url   state  \
# 341328385    https://github.com/pandas-dev/pandas/pull/21921  closed
# 341342552    https://github.com/pandas-dev/pandas/pull/21922    open
# 341349059    https://github.com/pandas-dev/pandas/pull/21923  closed
# 341349603    https://github.com/pandas-dev/pandas/pull/21924  closed
# 341355270  https://github.com/pandas-dev/pandas/issues/21925    open
#
#                                                        title closed_by  \
# 341328385  BUG:Clip with a list-like threshold with a nan...   jreback
# 341342552  Concatenation of series of differing types sho...       NaN
# 341349059     [BUG] change types to Py_ssize_t to fix #21905   jreback
# 341349603         move rename functionality out of internals   jreback
# 341355270  Allow different methods of correlation when us...       NaN
#
#                    user assignees                     labels  \
# 341328385       makbigc       NaN    ['Bug', 'Missing-data']
# 341342552        xhochy       NaN  ['Bug', 'ExtensionArray']
# 341349059  jbrockmendel       NaN           ['32bit', 'Bug']
# 341349603  jbrockmendel       NaN  ['Internals', 'Refactor']
# 341355270       dsaxton       NaN   ['Apply', 'Enhancement']
#
#                        milestone  \
# 341328385                 0.23.4
# 341342552                    NaN
# 341349059                 0.24.0
# 341349603                 0.24.0
# 341355270  Contributions Welcome
#
#                                               pull_request
# 341328385  https://github.com/pandas-dev/pandas/pull/21921
# 341342552  https://github.com/pandas-dev/pandas/pull/21922
# 341349059  https://github.com/pandas-dev/pandas/pull/21923
# 341349603  https://github.com/pandas-dev/pandas/pull/21924
# 341355270                                              NaN

# %% [markdown]
# **NaN value handling:**

# %%
# get the number of Nan values for each column
issues_df.isnull().sum()
# Out:
# body              17
# closed_at        594
# comments           0
# created_at         0
# html_url           0
# state              0
# title              0
# closed_by        575
# user               0
# assignees       1958
# labels           193
# milestone        850
# pull_request     974
# dtype: int64

# %% [markdown]
# - **body:** an issue doesn't need to have a body, the problem can be explained in the title as it can be seen in this [example](https://github.com/pandas-dev/pandas/pull/22038)
# - **closed_at:** an open issue does not have a closed time and thus it is specified as Nan as it can be seen in this [example](https://github.com/pandas-dev/pandas/pull/21922)
# - **closed_by:** if an issue is not closed, it does not have a closed_by attribute. Note that the # of closed_by Nans is smaller then the number of closed_at Nans which can be explained by the fact that some issues might get reopened leading to this state as it can be seen in [this reopened issue](https://github.com/pandas-dev/pandas/issues/22116)
# - **assignees, labels and milestones** are optional fields for a certain issue and thus having Nans is acceptable
# - **pull_request:** an issue that does not have a pull_request is an GitHub issue otherwise it is a pull request (the GitHub API does not separate the two)

# %%
# display a sample
comments_df.head(5)
# Out:
#                                                         body  \
# 142689649  It seems OK to me. I assume we still have at l...
# 142690747  @srowen So this changes it so that all of the ...
# 142699766    [Test build #42915 has finished](https://amp...
# 142701746    [Test build #42916 has finished](https://amp...
# 142733640  cc'ing a few people: @mccheah (who wrote the o...
#
#                     created_at           updated_at     parent
# 142689649  2015-09-23 18:28:51  2015-09-23 18:28:51  107977847
# 142690747  2015-09-23 18:33:36  2015-09-23 18:33:36  107977847
# 142699766  2015-09-23 19:07:00  2015-09-23 19:07:00  107977847
# 142701746  2015-09-23 19:16:05  2015-09-23 19:16:05  107977847
# 142733640  2015-09-23 21:24:23  2015-09-23 21:24:23  108009077

# %% [markdown]
# - No columns will be dropped because all provide relevent information for later analysis.

# %%
# get the number of Nan values for each column
comments_df.isnull().sum()
# Out:
# body          0
# created_at    0
# updated_at    0
# parent        0
# dtype: int64

# %% [markdown]
# - No null values are present in comments of issues data.

# %% [markdown]
# ### <span style='color:green'> 2.2 - Projects data </span>

# %%
# use the id column as the index
commits_df = commits_df.set_index('id')
# display a sample
commits_df.head(5)
# Out:
#                                                  project  age  \
# id
# bc9b0d6b0aebc469b2f84664de590b59d6fdf79f  Microsoft/CNTK   -1
# 61694509551f38e031c74f3d9409b44fe50224cf  Microsoft/CNTK   -1
# 9515bfbd104a5ba4f4214e2d883e8e3af2acd01c  Microsoft/CNTK   -1
# 52eabc6e8852b6a8342ae304a606663f7f8ae15f  Microsoft/CNTK   -1
# f5a490c2afbffd515a9ddfbe3053e76bb9cbfe17  Microsoft/CNTK   -1
#
#                                                                        author_email  \
# id
# bc9b0d6b0aebc469b2f84664de590b59d6fdf79f  do****@stggpu1.redmond.corp.microsoft.com
# 61694509551f38e031c74f3d9409b44fe50224cf  do****@stggpu1.redmond.corp.microsoft.com
# 9515bfbd104a5ba4f4214e2d883e8e3af2acd01c                      jd*****@microsoft.com
# 52eabc6e8852b6a8342ae304a606663f7f8ae15f                       do****@microsoft.com
# f5a490c2afbffd515a9ddfbe3053e76bb9cbfe17                       do****@microsoft.com
#
#                                              author_email_dedup   author_name  \
# id
# bc9b0d6b0aebc469b2f84664de590b59d6fdf79f  al*****@microsoft.com       unknown
# 61694509551f38e031c74f3d9409b44fe50224cf  al*****@microsoft.com       unknown
# 9515bfbd104a5ba4f4214e2d883e8e3af2acd01c  jd*****@microsoft.com  Jasha Droppo
# 52eabc6e8852b6a8342ae304a606663f7f8ae15f   do****@microsoft.com       Dong Yu
# f5a490c2afbffd515a9ddfbe3053e76bb9cbfe17   do****@microsoft.com       Dong Yu
#
#                                          author_name_dedup  \
# id
# bc9b0d6b0aebc469b2f84664de590b59d6fdf79f     Yinggong ZHAO
# 61694509551f38e031c74f3d9409b44fe50224cf     Yinggong ZHAO
# 9515bfbd104a5ba4f4214e2d883e8e3af2acd01c      Jasha Droppo
# 52eabc6e8852b6a8342ae304a606663f7f8ae15f           Dong Yu
# f5a490c2afbffd515a9ddfbe3053e76bb9cbfe17           Dong Yu
#
#                                                  author_time  \
# id
# bc9b0d6b0aebc469b2f84664de590b59d6fdf79f 2014-07-29 10:12:20
# 61694509551f38e031c74f3d9409b44fe50224cf 2014-08-29 16:21:42
# 9515bfbd104a5ba4f4214e2d883e8e3af2acd01c 2014-08-31 12:27:42
# 52eabc6e8852b6a8342ae304a606663f7f8ae15f 2014-09-01 14:43:21
# f5a490c2afbffd515a9ddfbe3053e76bb9cbfe17 2014-09-02 17:16:40
#
#                                                                     committer_email  \
# id
# bc9b0d6b0aebc469b2f84664de590b59d6fdf79f  do****@stggpu1.redmond.corp.microsoft.com
# 61694509551f38e031c74f3d9409b44fe50224cf  do****@stggpu1.redmond.corp.microsoft.com
# 9515bfbd104a5ba4f4214e2d883e8e3af2acd01c                      jd*****@microsoft.com
# 52eabc6e8852b6a8342ae304a606663f7f8ae15f                       do****@microsoft.com
# f5a490c2afbffd515a9ddfbe3053e76bb9cbfe17                       do****@microsoft.com
#
#                                           committer_email_dedup  \
# id
# bc9b0d6b0aebc469b2f84664de590b59d6fdf79f  al*****@microsoft.com
# 61694509551f38e031c74f3d9409b44fe50224cf  al*****@microsoft.com
# 9515bfbd104a5ba4f4214e2d883e8e3af2acd01c  jd*****@microsoft.com
# 52eabc6e8852b6a8342ae304a606663f7f8ae15f   do****@microsoft.com
# f5a490c2afbffd515a9ddfbe3053e76bb9cbfe17   do****@microsoft.com
#
#                                          committer_name    ...    comp_d  \
# id                                                         ...
# bc9b0d6b0aebc469b2f84664de590b59d6fdf79f        unknown    ...         0
# 61694509551f38e031c74f3d9409b44fe50224cf        unknown    ...         0
# 9515bfbd104a5ba4f4214e2d883e8e3af2acd01c   Jasha Droppo    ...         0
# 52eabc6e8852b6a8342ae304a606663f7f8ae15f        Dong Yu    ...         0
# f5a490c2afbffd515a9ddfbe3053e76bb9cbfe17        Dong Yu    ...         3
#
#                                           comp_i  delay  ismerge  loc_d  \
# id
# bc9b0d6b0aebc469b2f84664de590b59d6fdf79f       0      0    False      0
# 61694509551f38e031c74f3d9409b44fe50224cf  248008      0    False      0
# 9515bfbd104a5ba4f4214e2d883e8e3af2acd01c       0      0    False      0
# 52eabc6e8852b6a8342ae304a606663f7f8ae15f       0      0    False      1
# f5a490c2afbffd515a9ddfbe3053e76bb9cbfe17       3      0    False      1
#
#                                            loc_i  \
# id
# bc9b0d6b0aebc469b2f84664de590b59d6fdf79f       0
# 61694509551f38e031c74f3d9409b44fe50224cf  139349
# 9515bfbd104a5ba4f4214e2d883e8e3af2acd01c       0
# 52eabc6e8852b6a8342ae304a606663f7f8ae15f       0
# f5a490c2afbffd515a9ddfbe3053e76bb9cbfe17       1
#
#                                                                                     message  \
# id
# bc9b0d6b0aebc469b2f84664de590b59d6fdf79f                                             test\n
# 61694509551f38e031c74f3d9409b44fe50224cf                            First Release of CNTK\n
# 9515bfbd104a5ba4f4214e2d883e8e3af2acd01c  Added the ASR/TIMIT/decoding to ExampleSetups ...
# 52eabc6e8852b6a8342ae304a606663f7f8ae15f               remove #include SimpleCNNBuilder.h\n
# f5a490c2afbffd515a9ddfbe3053e76bb9cbfe17  remove ";" from "if (pass == ndlPassInitial);"...
#
#                                           ndiffs nfiles  squashof
# id
# bc9b0d6b0aebc469b2f84664de590b59d6fdf79f       1      1        -1
# 61694509551f38e031c74f3d9409b44fe50224cf       1    492        -1
# 9515bfbd104a5ba4f4214e2d883e8e3af2acd01c       1      6        -1
# 52eabc6e8852b6a8342ae304a606663f7f8ae15f       1      1        -1
# f5a490c2afbffd515a9ddfbe3053e76bb9cbfe17       1      1        -1
#
# [5 rows x 22 columns]

# %% [markdown]
# - None of the columns will be droped because all are needed later on for further analysis steps.

# %%
# get the number of Nan values for each column
commits_df.isnull().sum()
# Out:
# project                      0
# age                          0
# author_email                 0
# author_email_dedup           0
# author_name                  0
# author_name_dedup            0
# author_time                  0
# committer_email              0
# committer_email_dedup    22313
# committer_name               0
# committer_name_dedup     22313
# committer_time               0
# comp_d                       0
# comp_i                       0
# delay                        0
# ismerge                      0
# loc_d                        0
# loc_i                        0
# message                      0
# ndiffs                       0
# nfiles                       0
# squashof                     0
# dtype: int64

# %% [markdown]
# - The only present Nans are in `committer_email_dedup` and `committer_name_dedup` which makes sense because these represent deduplicated information which is optional and thus no necessairy.

# %% [markdown]
# ### <span style='color:green'> 2.3 - StackOverflow data</span>

# %%
# germain
# display a sample
stackoverflow_df.head(5)

# %% [markdown]
# - None of the columns will be droped because all are needed later on for further analysis steps.

# %%
# germain
# get the number of Nan values for each column
stackoverflow_df.isnull().sum()

# %% [markdown]
# - No null values are present in comments of issues data.

# %% [markdown]
# ### <span style='color:green'> 2.4 - Reddit data</span>

# %%
# germain
# display a sample
reddit_df.head(5)

# %% [markdown]
# - None of the columns will be droped because all are needed later on for further analysis steps.

# %%
# germain
# get the number of Nan values for each column
reddit_df.isnull().sum()

# %% [markdown]
# - No null values are present in comments of issues data.

# %% [markdown]
# # 4. Data Preparation:
# - converting data type
# - filter / transform
# - Description
# - distributions
# - correlations / dependance

# %% [markdown]
# ### <span style='color:green'> 2.1 - GitHub API data (Issues & Comments) </span>

# %%
# check the types of each column
issues_df.dtypes
# Out:
# body            object
# closed_at       object
# comments         int64
# created_at      object
# html_url        object
# state           object
# title           object
# closed_by       object
# user            object
# assignees       object
# labels          object
# milestone       object
# pull_request    object
# dtype: object

# %%
# convert each column to it's appropriate type
issues_df.closed_at = issues_df.closed_at.astype('datetime64')
issues_df.created_at = issues_df.created_at.astype('datetime64')
# germain change this to 'project' instead of 'html_url'
issues_df.state = issues_df.state.astype('category')
issues_df.user = issues_df.user.astype(list)

# %%
issues_df.dtypes
# Out:
# body                    object
# closed_at       datetime64[ns]
# comments                 int64
# created_at      datetime64[ns]
# html_url                object
# state                 category
# title                   object
# closed_by               object
# user                    object
# assignees               object
# labels                  object
# milestone               object
# pull_request            object
# dtype: object

# %%
# decribe the comments column (only int column)
pd.DataFrame(issues_df['comments'].describe())
# Out:
#           comments
# count  1963.000000
# mean      5.201732
# std       6.481846
# min       0.000000
# 25%       2.000000
# 50%       4.000000
# 75%       6.000000
# max      94.000000

# %%
# decribe the closed_at, created_at
pd.DataFrame(issues_df[['closed_at','created_at']].describe())
# Out:
#                   closed_at           created_at
# count                  1369                 1963
# unique                 1203                 1963
# top     2018-11-18 18:32:51  2018-08-09 11:48:09
# freq                      3                    1
# first   2018-07-16 15:18:48  2018-07-15 15:18:30
# last    2018-11-24 15:43:57  2018-11-24 09:51:00

# %%
pd.DataFrame(issues_df['state'].describe())
# Out:
#          state
# count     1963
# unique       2
# top     closed
# freq      1369

# %%
# check the types of each column
comments_df.dtypes
# Out:
# body          object
# created_at    object
# updated_at    object
# parent         int64
# dtype: object

# %%
# convert to appropriate types
comments_df.updated_at = comments_df.updated_at.astype('datetime64')
comments_df.created_at = comments_df.created_at.astype('datetime64')
comments_df.dtypes
# Out:
# body                  object
# created_at    datetime64[ns]
# updated_at    datetime64[ns]
# parent                 int64
# dtype: object

# %%
# describe the data
comments_df[['updated_at','created_at']].describe()
# Out:
#                  updated_at           created_at
# count                171985               171985
# unique               170599               170586
# top     2018-10-22 16:36:50  2018-10-22 16:36:50
# freq                     13                   13
# first   2015-09-23 18:28:51  2015-09-23 18:28:51
# last    2018-11-24 17:31:16  2018-11-24 15:56:21

# %% [markdown]
# Based on sample used for this milestone, everything is acceptable and makes sense so far in terms of value ranges and distribution, meaning:
# - when it comes to time values, they are in acceptable year ranges (by looking at the first and last times).
# - Normal value ranges for the min comments and maximum observed (min is 0 and max is 94 for this sample of the data).
# - the categorical data checks out as well.

# %% [markdown]
# **Note: this is only a sample of the data we want to retrieve. Therefore, we cannot perform correlation/distribution analysis yet (since we need the full data for that).**
#
# (This is because the GitHub API, which we're using to build this additional dataset, has an hourly limit of 5000 requests/hour. We're retrieving around 300,000 issues in total, spread across all the repositories we're studying, as well as all of their comments. In total, this amounts to half a million to a million requests. We expect this to finish around Monday. For implementation details, please check the `retrieve_additional_data_github.ipynb` notebook.)

# %% [markdown]
# ### <span style='color:green'> 2.2 - Project data </span>

# %%
# check data types
commits_df.dtypes
# Out:
# project                          object
# age                               int64
# author_email                     object
# author_email_dedup               object
# author_name                      object
# author_name_dedup                object
# author_time              datetime64[ns]
# committer_email                  object
# committer_email_dedup            object
# committer_name                   object
# committer_name_dedup             object
# committer_time           datetime64[ns]
# comp_d                            int64
# comp_i                            int64
# delay                             int64
# ismerge                            bool
# loc_d                             int64
# loc_i                             int64
# message                          object
# ndiffs                            int64
# nfiles                            int64
# squashof                          int64
# dtype: object

# %% [markdown]
# All columns have already the appropriate data type. :-)

# %%
# describe the integer data
commits_df.describe()
# Out:
#                 age         comp_d        comp_i         delay          loc_d  \
# count  7.600160e+05  760016.000000  7.600160e+05  7.600160e+05  760016.000000
# mean   1.618832e+04     850.402367  1.653404e+03 -1.844900e+06     483.495596
# std    9.822351e+05    7397.177527  1.483075e+04  1.064061e+07    5396.217236
# min   -1.091670e+05       0.000000  0.000000e+00 -3.833697e+08       0.000000
# 25%   -1.000000e+00       0.000000  1.000000e+00 -5.957550e+04       0.000000
# 50%   -1.000000e+00       5.000000  1.400000e+01  0.000000e+00       3.000000
# 75%   -1.000000e+00      47.000000  1.010000e+02  0.000000e+00      27.000000
# max    2.594301e+08  956073.000000  2.569923e+06  3.153577e+07  826769.000000
#
#               loc_i         ndiffs         nfiles       squashof
# count  7.600160e+05  760016.000000  760016.000000  760016.000000
# mean   1.134851e+03       1.155940      35.957244     309.021527
# std    1.089662e+04       0.363096     261.872079    1976.791309
# min    0.000000e+00       1.000000       0.000000      -1.000000
# 25%    1.000000e+00       1.000000       1.000000      -1.000000
# 50%    1.000000e+01       1.000000       2.000000      -1.000000
# 75%    6.500000e+01       1.000000       5.000000      -1.000000
# max    1.435685e+06       6.000000   61451.000000   44150.000000

# %%
# describe the time data
commits_df[['author_time','committer_time']].describe()
# Out:
#                 author_time       committer_time
# count                760016               760016
# unique               575196               571758
# top     2016-06-03 15:38:25  2016-04-21 10:56:45
# freq                    170                  979
# first   1999-12-29 14:20:26  1999-12-29 14:20:26
# last    2018-12-31 09:53:18  2018-01-19 21:29:15

# %%
commits_df['ismerge'].describe()
# Out:
# count     760016
# unique         2
# top        False
# freq      617053
# Name: ismerge, dtype: object

# %% [markdown]
# Everything is acceptable and makes sense so far in terms of value ranges and distribution, meaning:
# - when it comes to time values, they are in acceptable year ranges (by looking at the first and last times `1999-2018` which makes sense).
# - Normal value ranges (min, max) for the integer type data as show in the above data frame.
# - the categorical data (ismerge) checks out as well.
#
# *Note: in regards to the huge number for age, this is the result of it being in seconds. The max value corresponds to arounnd 8 years which fall into the observed time range of the commits (1999-2018).*

# %%
commits_df.corr()[commits_df.corr() > 0.3]
# Out:
#           age    comp_d    comp_i  delay   ismerge     loc_d     loc_i  \
# age       1.0       NaN       NaN    NaN       NaN       NaN       NaN
# comp_d    NaN  1.000000  0.471823    NaN       NaN  0.965573  0.433444
# comp_i    NaN  0.471823  1.000000    NaN       NaN  0.387511  0.985779
# delay     NaN       NaN       NaN    1.0       NaN       NaN       NaN
# ismerge   NaN       NaN       NaN    NaN  1.000000       NaN       NaN
# loc_d     NaN  0.965573  0.387511    NaN       NaN  1.000000  0.369714
# loc_i     NaN  0.433444  0.985779    NaN       NaN  0.369714  1.000000
# ndiffs    NaN       NaN       NaN    NaN  0.892249       NaN       NaN
# nfiles    NaN  0.463603  0.557978    NaN       NaN  0.423406  0.560638
# squashof  NaN       NaN       NaN    NaN  0.325822       NaN       NaN
#
#             ndiffs    nfiles  squashof
# age            NaN       NaN       NaN
# comp_d         NaN  0.463603       NaN
# comp_i         NaN  0.557978       NaN
# delay          NaN       NaN       NaN
# ismerge   0.892249       NaN  0.325822
# loc_d          NaN  0.423406       NaN
# loc_i          NaN  0.560638       NaN
# ndiffs    1.000000       NaN       NaN
# nfiles         NaN  1.000000       NaN
# squashof       NaN       NaN  1.000000

# %%
commits_df = commits_df.drop('ismerge', axis=1)

# %% [markdown]
# These correlations make sense given the definition of our data columns.
#
# For example, `ismerge` and `ndiffs` are correlated since `ismerge` is True whenever there are more than two parents / is a git squash, and `ndiffs` is the number of diffs and parents of a commit. In fact, we can obtain the same information in `ismerge` from `ndiffs` and `squashof`. We therefore decide to drop `ismerge`.
#
# However, the other correlated variables might still be useful to us during our analysis.
# For instance, if we consider `comp_d` (whitespace complexity deleted, e.g. number of spaces removed by a commit) and `loc_d` (lines of code deleted by a commit), they're obviously highly correlated (deleted lines of codes = deleted spaces) but can still be useful together in some cases. If an author's commits are mostly removing whitespace complexity (without removing a lot of lines of code), then we might be able to classify this author as someone who mostly does "Code style checking/code guidelines enforcer" or similar.
#
# For this reason, we choose not to remove any of the remaining columns at this stage.

# %% [markdown]
# # 5. Plan Update
# - updated your plan in a reasonable way
# - reflecting your improved knowledge
# - discuss how your data suits your project needs
# - discuss the methods you’re going to use, giving their essential mathematical details
# - potentially discussing alternatives to your choices that you considered but dropped.
